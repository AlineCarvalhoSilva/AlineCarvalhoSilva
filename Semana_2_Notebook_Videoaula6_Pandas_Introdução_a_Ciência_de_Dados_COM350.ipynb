# %% [markdown]
# <a href="https://colab.research.google.com/github/AlineCarvalhoSilva/AlineCarvalhoSilva/blob/main/Semana_2_Notebook_Videoaula6_Pandas_Introdu%C3%A7%C3%A3o_a_Ci%C3%AAncia_de_Dados_COM350.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Demonstração Pandas
# ###Disciplina - Introdução a Ciência de Dados - Univesp
# ###Videoaula 6
# ###Prof. Dr. José Eduardo Santarem Segundo

# %% [markdown]
# #Importar Bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Series (observe o índice do lado esquerdo)

# %%
s1=pd.Series([1,2,-5,0])

# %%
s1
# Out:
# 0    1
# 1    2
# 2   -5
# 3    0
# dtype: int64

# %%
s1.values
# Out:
# array([ 1,  2, -5,  0])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s2=pd.Series([1,2,-5,0], index=['a','b', 'c', 'd'])

# %%
s2
# Out:
# a    1
# b    2
# c   -5
# d    0
# dtype: int64

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s2['a']=1000

# %%
s2
# Out:
# a    1000
# b       2
# c      -5
# d       0
# dtype: int64

# %% [markdown]
# #Comparação

# %%
s2[s2>0]
# Out:
# a    1000
# b       2
# dtype: int64

# %% [markdown]
# #Algebra

# %%
s2*2
# Out:
# a    2000
# b       4
# c     -10
# d       0
# dtype: int64

# %%
s2
# Out:
# a    1000
# b       2
# c      -5
# d       0
# dtype: int64

# %%
s2.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# dtype: bool

# %% [markdown]
# #Dataframe

# %% [markdown]
# #Criar Dataframe

# %%
dados={'estado':['SP', 'MG','PR','SP','MG','PR'], 'ano':[2019, 2019,2019, 2020,2020,2020], 'pop':[45.9, 21.2,16.9,46.6,21.4,17.3]}
df1=pd.DataFrame(dados)

# %%
df1
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9
# 3     SP  2020  46.6
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.head(2)
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2

# %% [markdown]
# #Visualizar partes Dataframe

# %%
df1.tail(2)
# Out:
#   estado   ano   pop
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.sample(2)
# Out:
#   estado   ano   pop
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %% [markdown]
# #Novo DF a partir o anterior (veja as colunas)

# %%
df2=pd.DataFrame(dados,columns=['ano','estado','pop'])

# %%
df2
# Out:
#     ano estado   pop
# 0  2019     SP  45.9
# 1  2019     MG  21.2
# 2  2019     PR  16.9
# 3  2020     SP  46.6
# 4  2020     MG  21.4
# 5  2020     PR  17.3

# %% [markdown]
# #Observar DF

# %%
df2['estado']
# Out:
# 0    SP
# 1    MG
# 2    PR
# 3    SP
# 4    MG
# 5    PR
# Name: estado, dtype: object

# %%
df2.ano
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2020
# 4    2020
# 5    2020
# Name: ano, dtype: int64

# %%
df2.dtypes
# Out:
# ano         int64
# estado     object
# pop       float64
# dtype: object

# %% [markdown]
# #Atribuir Valores

# %%
df2['estimativa']=50

# %%
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9          50
# 1  2019     MG  21.2          50
# 2  2019     PR  16.9          50
# 3  2020     SP  46.6          50
# 4  2020     MG  21.4          50
# 5  2020     PR  17.3          50

# %%
df2['estimativa']=np.arange(6)

# %%
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9           0
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %%
df3=df2

# %%
df3
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9           0
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %%
df3=df2['ano']

# %%
df3
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2020
# 4    2020
# 5    2020
# Name: ano, dtype: int64

# %%
df2['Não Paraná']=df2.estado!='PR'

# %%
df2
# Out:
#     ano estado   pop  estimativa  Não Paraná
# 0  2019     SP  45.9           0        True
# 1  2019     MG  21.2           1        True
# 2  2019     PR  16.9           2       False
# 3  2020     SP  46.6           3        True
# 4  2020     MG  21.4           4        True
# 5  2020     PR  17.3           5       False

# %% [markdown]
# #Excluir Coluna

# %%
del df2['Não Paraná']

# %%
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9           0
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %% [markdown]
# #Entender o DataFrame

# %%
df2.shape
# Out:
# (6, 4)

# %%
df2.shape[0]
# Out:
# 6

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df2.columns
# Out:
# Index(['ano', 'estado', 'pop', 'estimativa'], dtype='object')

# %%
df2.count()
# Out:
# ano           6
# estado        6
# pop           6
# estimativa    6
# dtype: int64

# %% [markdown]
# #Alterar Informação das Colunas

# %%
df2.columns=['Ano','estado','Populacao','estimativa']

# %%
df2
# Out:
#     Ano estado  Populacao  estimativa
# 0  2019     SP       45.9           0
# 1  2019     MG       21.2           1
# 2  2019     PR       16.9           2
# 3  2020     SP       46.6           3
# 4  2020     MG       21.4           4
# 5  2020     PR       17.3           5

# %% [markdown]
# #Analisar o DataFrame

# %%
df2.describe(include='all')
# Out:
#                 Ano estado  Populacao  estimativa
# count      6.000000      6   6.000000    6.000000
# unique          NaN      3        NaN         NaN
# top             NaN     SP        NaN         NaN
# freq            NaN      2        NaN         NaN
# mean    2019.500000    NaN  28.216667    2.500000
# std        0.547723    NaN  14.096725    1.870829
# min     2019.000000    NaN  16.900000    0.000000
# 25%     2019.000000    NaN  18.275000    1.250000
# 50%     2019.500000    NaN  21.300000    2.500000
# 75%     2020.000000    NaN  39.775000    3.750000
# max     2020.000000    NaN  46.600000    5.000000

# %% [markdown]
# #Alterar valores e  consultar dados

# %%
df2['Ano']=df2['Ano']+2

# %%
df2
# Out:
#     Ano estado  Populacao  estimativa
# 0  2021     SP       45.9           0
# 1  2021     MG       21.2           1
# 2  2021     PR       16.9           2
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %%
df2[df2['Ano']>2021]
# Out:
#     Ano estado  Populacao  estimativa
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %%
df4=df2[df2['Ano']>2021]

# %%
df4
# Out:
#     Ano estado  Populacao  estimativa
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %% [markdown]
# #Excluir Colunas

# %%
df4.drop('Ano', axis='columns')
# Out:
#   estado  Populacao  estimativa
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %%
df4
# Out:
#     Ano estado  Populacao  estimativa
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %%
df2
# Out:
#     Ano estado  Populacao  estimativa
# 0  2021     SP       45.9           0
# 1  2021     MG       21.2           1
# 2  2021     PR       16.9           2
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %%
df2.drop('Ano', axis='columns', inplace=True)

# %%
df2
# Out:
#   estado  Populacao  estimativa
# 0     SP       45.9           0
# 1     MG       21.2           1
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %% [markdown]
# #Excluir Linhas

# %%
df2.drop([0,1])
# Out:
#   estado  Populacao  estimativa
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %%
df2
# Out:
#   estado  Populacao  estimativa
# 0     SP       45.9           0
# 1     MG       21.2           1
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %% [markdown]
# ###Observe a propagação na exclusão definitiva

# %%
dflinhas=df2

# %%
dflinhas.drop([0,1],inplace=True)

# %%
dflinhas
# Out:
#   estado  Populacao  estimativa
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %%
df2
# Out:
#   estado  Populacao  estimativa
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %% [markdown]
# #Ver Dados de linhas

# %%
df2.iloc[0]
# Out:
# estado          PR
# Populacao     16.9
# estimativa       2
# Name: 2, dtype: object

# %%
df2.iloc[1:3]
# Out:
#   estado  Populacao  estimativa
# 3     SP       46.6           3
# 4     MG       21.4           4

# %%
df2.iloc[1:3,[1,2]]
# Out:
#    Populacao  estimativa
# 3       46.6           3
# 4       21.4           4

# %%
df2
# Out:
#   estado  Populacao  estimativa
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5
